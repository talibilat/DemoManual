# %%
import pandas as pd

# %%
df = pd.read_csv('detailed_results_20250411_172857.csv')
df.head()
# Out:
#     model embedding_type                                           question  \
# 0  gpt-4o         openai                      How does refer-a-friend work?
# 1  gpt-4o         openai       How does the Voy weight loss programme work?
# 2  gpt-4o         openai  Is this a safe and effective way to manage wei...
# 3  gpt-4o         openai  Are there any medical conditions that might di...
# 4  gpt-4o         openai  Can I restart my subscription at a higher dosage?
#
#                                         ground_truth  \
# 0  We're delighted that you're considering sharin...
# 1  Voy is the last weight loss programme you'll e...
# 2  Absolutely! GLP-1 medications, when used along...
# 3  At Voy, we prioritise your safety and well-bei...
# 4  Yes, for Wegovy and Mounjaro, you can start on...
#
#                                   retrieved_contexts  \
# 0  To find out if you're eligible for our treatme...
# 1  You can also track your own progress within th...
# ...
