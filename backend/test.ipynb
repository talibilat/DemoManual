# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('data/faqs/faqs.csv')
df.head()
# Out:
#                                             page_url  \
# 0  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 1  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 2  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 3  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 4  https://joinvoy.zendesk.com/hc/en-gb/articles/...
#
#                                           page_title  \
# 0  Why doesn’t VOY mention prescription medicatio...
# 1                     Information about Wegovy – Voy
# 2                     Information about Wegovy – Voy
# 3                     Information about Wegovy – Voy
# 4                     Information about Wegovy – Voy
#
#                                             question  \
# 0  Why doesn’t VOY mention prescription medicatio...
# 1                                    What is Wegovy?
# 2                              How does Wegovy work?
# 3                                How to take Wegovy?
# ...

# %%
df.drop_duplicates(subset=['answer'], inplace=True)
len(df)
# Out:
# 59

# %%
p = df.drop_duplicates()

len(p)
# Out:
# 59

# %%
df
# Out:
#                                              page_url  \
# 0   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 1   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 2   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 3   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 4   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 5   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 6   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 7   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 8   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 9   https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 10  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 11  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 12  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 13  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 14  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# 15  https://joinvoy.zendesk.com/hc/en-gb/articles/...
# ...
